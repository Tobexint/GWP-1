# %%
import pandas as pd
from fredapi import Fred
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fred = Fred(api_key='eb320673f63b8599444712fa1e564423')

# %%
series = {
    "GDP": "GDP",
    "Unemployment": "UNRATE",
    "Inflation": "CPIAUCSL",
    "InterestRate": "FEDFUNDS"
}

df = pd.DataFrame()

for name, code in series.items():
    df[name] = fred.get_series(code)

print(df.head())
# Out:
#                 GDP  Unemployment  Inflation  InterestRate
# 1946-01-01      NaN           NaN        NaN           NaN
# 1946-04-01      NaN           NaN        NaN           NaN
# 1946-07-01      NaN           NaN        NaN           NaN
# 1946-10-01      NaN           NaN        NaN           NaN
# 1947-01-01  243.164           NaN      21.48           NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 321 entries, 1946-01-01 to 2026-01-01
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   GDP           317 non-null    float64
#  1   Unemployment  312 non-null    float64
#  2   Inflation     316 non-null    float64
#  3   InterestRate  287 non-null    float64
# dtypes: float64(4)
# memory usage: 12.5 KB

# %%
df.shape
# Out:
# (321, 4)

# %%
print(df.isnull().sum())
# Out:
# GDP              4
# Unemployment     9
# Inflation        5
# InterestRate    34
# dtype: int64

# %%
df = df.dropna()
df
# Out:
#                   GDP  Unemployment  Inflation  InterestRate
# 1954-07-01    390.996           5.8     26.860          0.80
# 1954-10-01    399.734           5.7     26.720          0.85
# 1955-01-01    413.073           4.9     26.770          1.39
# 1955-04-01    421.532           4.7     26.790          1.43
# 1955-07-01    430.221           4.0     26.760          1.68
# ...               ...           ...        ...           ...
# 2024-10-01  29825.182           4.1    315.631          4.83
# 2025-01-01  30042.113           4.0    318.961          4.33
# 2025-04-01  30485.729           4.2    320.302          4.33
# 2025-07-01  31098.027           4.3    322.169          4.33
# 2026-01-01  31865.721           4.3    326.588          3.64
#
# [286 rows x 4 columns]

# %%
df.head()
# Out:
#                 GDP  Unemployment  Inflation  InterestRate
# 1954-07-01  390.996           5.8      26.86          0.80
# 1954-10-01  399.734           5.7      26.72          0.85
# 1955-01-01  413.073           4.9      26.77          1.39
# 1955-04-01  421.532           4.7      26.79          1.43
# 1955-07-01  430.221           4.0      26.76          1.68

# %%
df.shape
# Out:
# (286, 4)

# %%
print(df.isnull().sum())
# Out:
# GDP             0
# Unemployment    0
# Inflation       0
# InterestRate    0
# dtype: int64

# %%
print(df.corr())
# Out:
#                    GDP  Unemployment  Inflation  InterestRate
# GDP           1.000000     -0.120115   0.974400     -0.425668
# Unemployment -0.120115      1.000000  -0.026332      0.053704
# Inflation     0.974400     -0.026332   1.000000     -0.380453
# InterestRate -0.425668      0.053704  -0.380453      1.000000

# %%
df.describe()
# Out:
#                 GDP  Unemployment   Inflation  InterestRate
# count    286.000000    286.000000  286.000000    286.000000
# mean    8531.674857      5.817483  134.120049      4.600909
# std     8207.013354      1.703673   87.655154      3.592778
# min      390.996000      3.400000   26.720000      0.050000
# 25%     1272.418250      4.500000   41.575000      1.770000
# 50%     5916.364500      5.600000  128.200000      4.275000
# 75%    14444.387000      6.875000  211.247250      6.087500
# max    31865.721000     14.800000  326.588000     19.080000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 286 entries, 1954-07-01 to 2026-01-01
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   GDP           286 non-null    float64
#  1   Unemployment  286 non-null    float64
#  2   Inflation     286 non-null    float64
#  3   InterestRate  286 non-null    float64
# dtypes: float64(4)
# memory usage: 11.2 KB

# %%
plt.figure(figsize=(10, 5))

df["GDP"].plot()

plt.title("US Gross Domestic Product (GDP)")
plt.xlabel("Year")
plt.ylabel("GDP (Billions of Dollars)")
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(10, 5))

df["Unemployment"].hist(bins=20)

plt.title("US Unemployment Rate")
plt.xlabel("Year")
plt.ylabel("Unemployment Rate (%)")
plt.grid(True)

plt.show()

# %%
df.plot.box(figsize=(8,5))
plt.show()

# %%
plt.figure(figsize=(10, 5))

df["Inflation"].plot()

plt.title("US Consumer Price Index (CPI)")
plt.xlabel("Year")
plt.ylabel("Consumer Price Index")
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(10, 5))

df["InterestRate"].plot()

plt.title("Federal Funds Rate")
plt.xlabel("Year")
plt.ylabel("Interest Rate (%)")
plt.grid(True)

plt.show()
